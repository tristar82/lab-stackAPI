# %% [markdown]
# # StackAPI
#
# #### Import the necessary libraries here:

# %%
import sys
print(sys.executable)

# %%
# your code here
import requests
import pandas as pd
from bs4 import BeautifulSoup
from stackapi import StackAPI
SITE = StackAPI('stackoverflow')

# %% [markdown]
# #### Question 1: Find the questions and answers of last month.

# %%
from stackapi import StackAPI
SITE = StackAPI('stackoverflow')
import requests

#comments = SITE.fetch('comments')
#questions = SITE.fetch('questions',)
#answers = SITE.fetch('answers')

# %%
questions = SITE.fetch('questions', fromdate=1570492800, todate=1573171200, order='desc', sort='creation')
answers = SITE.fetch('answers', fromdate=1570492800, todate=1573171200, order='desc',sort='creation')

# %%
url = 'https://api.stackexchange.com/2.2/questions?fromdate=1570752000&todate=1573171200&order=desc&sort=activity&site=stackoverflow'
requests.get(url)

# %%
questions['items']
# Out:
# [{'tags': ['javascript',
#    'file-upload',
#    'google-cloud-functions',
#    'dropbox-api',
#    'dropzone.js'],
#   'owner': {'reputation': 23,
#    'user_id': 2402551,
#    'user_type': 'registered',
#    'profile_image': 'https://www.gravatar.com/avatar/f8c2e6316c1228ff0a1018c7e41979cb?s=128&d=identicon&r=PG',
#    'display_name': 'Ian Brown',
#    'link': 'https://stackoverflow.com/users/2402551/ian-brown'},
#   'is_answered': False,
#   'view_count': 6,
#   'answer_count': 0,
#   'score': 0,
#   'last_activity_date': 1573171196,
#   'creation_date': 1573171196,
#   'question_id': 58758574,
#   'link': 'https://stackoverflow.com/questions/58758574/upload-ai-file-to-dropbox-through-firebase-functions-using-dropzone-but-no-base',
#   'title': 'Upload .AI file to Dropbox through Firebase Functions using Dropzone but no Base64 or file info included'},
#  {'tags': ['java', 'android', 'kotlin', 'webrtc'],
#   'owner': {'reputation': 90,
#    'user_id': 9382668,
# ...

# %%
values_q = [d.get('title') for d in questions['items']]

# %%
values_q
# Out:
# ['Upload .AI file to Dropbox through Firebase Functions using Dropzone but no Base64 or file info included',
#  'How do i add Voice Chat Feature to already Existing Video Conference Code WebRTC Android',
#  'How to reset TYPE_STEP_COUNTER sensor on a daily basis at a specific time, instead of every reboot',
#  'Powershell Check Current Date And Folder Modified Date',
#  'how to make sc spark context global to all modules without passing to function',
#  'Ways to save RDD to S3 using pyspark',
#  'Why isn&#39;t MongoDB simple read query working?',
#  'what&#39;s the correct way to create a typed Observable with RxJS?',
#  'Drawing a mixed stacked horizontal bar/line in chartjs',
#  'On Mobile why pageYOffset + clientHeight don&#39;t equal to scrollHeight?',
#  'LinearRegression on linerrud dataset',
#  'How to filter the data from excel before going to OLE DB destination',
#  'Nodejs Multer On Success get The return value',
#  'Volley jsonObjectRequest how to handle string result',
# ...

# %%
answers['items']

# %%
values_a = [d.get('answer_id') for d in answers['items']]

# %%
values_a

# %%
df_ans2 = pd.DataFrame(df_ans['items'])

# %%
df_qs2 = pd.DataFrame(df_qs['items'])

# %%
df_ans#['items']

# %%
df_ans2

# %% [markdown]
# #### Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
# your code here
questionsQ2 = SITE.fetch('questions', fromdate=1473257600, todate=1573171200, tagged='python', min=5, order='desc', sort='creation')

# %%
questionsQ2
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'tags': ['python', 'pandas', 'jupyter-notebook', 'jupyter'],
#    'owner': {'reputation': 1,
#     'user_id': 12340518,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/bda7a89ff60af5f2a4a9ba58dd4ceb1a?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'MouseOfGondor',
#     'link': 'https://stackoverflow.com/users/12340518/mouseofgondor'},
#    'is_answered': False,
#    'view_count': 31,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1573209782,
#    'creation_date': 1573170782,
#    'last_edit_date': 1573209782,
#    'question_id': 58758529,
#    'link': 'https://stackoverflow.com/questions/58758529/difficulties-with-jupyter-tab-auto-complete',
#    'title': 'Difficulties with Jupyter tab auto-complete'},
#   {'tags': ['python', 'currency', 'datacash'],
#    'owner': {'reputation': 1,
# ...

# %%
values_q2 = [[x.get('title') for x in questionsQ2['items'] ] , [x.get('score') for x in questionsQ2['items'] ]]

# %%
df_q2 = pd.DataFrame(values_q2)

# %%
df_q2 = pd.DataFrame.transpose(df_q2)

# %%
df_q2 = df_q2.rename(columns={0 :'Question', 1:'Score'})

# %%
df_q2.dtypes
# Out:
# Question    object
# Score       object
# Vote         int32
# dtype: object

# %%
df_q2['Vote'] =  df_q2['Score'].astype('int')  #convert dtype to string
df_q2
# Out:
#                                               Question Score  Vote
# 0          Difficulties with Jupyter tab auto-complete     0     0
# 1                    paying by coins with given pocket    -2    -2
# 2    Filtering time-localized index for hours inter...     0     0
# 3           Why wont my math game made in python open?    -1    -1
# 4    xarray select nearest lat/lon with multi-dimen...     0     0
# 5    Output comes class instance variable not just ...     0     0
# 6    How to group float data into different int-win...     0     0
# 7    How to fix &quot;module &#39;platform&#39; has...     0     0
# 8    How can I get HEX or RGB color code of the win...     0     0
# 9    pybind11 Redirect python sys.stdout to c++ fro...     1     1
# 10   how to display full sub window when using inte...     0     0
# 11   How to store highscores on an online database ...    -1    -1
# 12   I want to get a specific value from a data fra...     0     0
# ...

# %%
df_q2.sort_values(by=['Vote'], axis=0, ascending=False)
# Out:
#                                               Question Score  Vote
# 469  Python multiprocessing: Running a process afte...     6     6
# 329                       What is the .py{} extension?     4     4
# 301  Python jsonschema, allowing nothing, or requir...     3     3
# 335  Are there IEC 61131 / IEC 61499 PLC function b...     3     3
# 454                 Count number of cells in the image     3     3
# 460  Can I fix the mean of one component of a Gauss...     3     3
# 25   Is it a good idea to use &quot;is&quot; to che...     3     3
# 464  Converting commas to dots from excel file in p...     3     3
# 33   asyncio/aiohttp - How to make series of async ...     3     3
# 97   Trying to Install Sklearn on Python 3.8 Gives ...     2     2
# 171  IBM Cloud Object Storage Connection issue Wats...     2     2
# 475  How to fill a column in pandas dataframe based...     2     2
# 29   How can I remove columns of pandas dataframe c...     2     2
# ...

# %% [markdown]
# #### Question 3: Find the answers with id 6784 and 6473.

# %%
# your code here
badges = SITE.fetch('badges', ids=[6784, 6473])

# %%
badges

# %%
answersQ3 = SITE.fetch('/answers/{ids}/', ids=[6784, 6473])

# %%
answersQ3

# %%
/2.2/answers/6784,6473?order=desc&sort=activity&site=stackoverflow

# %%
questionsQ3 = SITE.fetch('answers', ids=[ 6784])

# %%
questionsQ3
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'owner': {'reputation': 22434,
#     'user_id': 758,
#     'user_type': 'registered',
#     'accept_rate': 77,
#     'profile_image': 'https://www.gravatar.com/avatar/0b4adc19284ed0751844d610555dc6b2?s=128&d=identicon&r=PG',
#     'display_name': 'Mark Renouf',
#     'link': 'https://stackoverflow.com/users/758/mark-renouf'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1218291583,
#    'creation_date': 1218291583,
#    'answer_id': 6784,
#    'question_id': 6778}]}

# %%
df_votedQuestions.loc[df_votedQuestions[‘Score’] >= 5]
